# %% [markdown]
# ## **Experiment Tracking and Model Management on Diamond Dataset**

# %% [markdown]
# ### Import the required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the Data

# %%
df = pd.read_csv('diamonds.csv')

df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df = df[['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z', 'price']]

df.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z  price
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335

# %% [markdown]
# ### Check size of dataset

# %%
df.shape
# Out:
# (53940, 10)

# %% [markdown]
# ### Check the Columns of dataset

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %% [markdown]
# ### Check the data types of the Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# ### Checking Statistical Analysis

# %%
df.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184      5.731157      5.734526
# std        0.474011      1.432621      2.234491      1.121761      1.142135
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z         price
# count  53940.000000  53940.000000
# mean       3.538734   3932.799722
# std        0.705699   3989.439738
# min        0.000000    326.000000
# 25%        2.910000    950.000000
# 50%        3.530000   2401.000000
# 75%        4.040000   5324.250000
# max       31.800000  18823.000000

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# x         10.74
# y         58.90
# z         31.80
# price  18823.00

# %% [markdown]
# ### Check Unique values

# %%
df.nunique()
# Out:
# carat        273
# cut            5
# color          7
# clarity        8
# depth        184
# table        127
# x            554
# y            552
# z            375
# price      11602
# dtype: int64

# %% [markdown]
# ### Check for Null values

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1. Univariate Analysis

# %%
sns.countplot(x = df['cut'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
sns.countplot(x = df['color'])
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x = df['clarity'])
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='count'>

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'carat'}>,
#         <AxesSubplot:title={'center':'depth'}>,
#         <AxesSubplot:title={'center':'table'}>],
#        [<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'y'}>,
#         <AxesSubplot:title={'center':'z'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.boxplot(df['carat'])

plt.title('weight of the diamond')
plt.xlabel('weight of the diamond')

plt.show()

# %%
plt.boxplot(df['depth'])

plt.title('depth of the diamond')
plt.xlabel('depth of the diamond')

plt.show()

# %%
plt.boxplot(df['x'])

plt.title('lentgh of diamond')
plt.xlabel('lentgh in mm')

plt.show()

# %%
plt.boxplot(df['y'])

plt.title('width of diamond')
plt.xlabel('widht in mm')

plt.show()

# %%
plt.boxplot(df['z'])

plt.title('depth of diamond')
plt.xlabel('depth in mm')

plt.show()

# %% [markdown]
# ### 2. Bivariate Analysis

# %%
plt.scatter(df['carat'], df['price'])

plt.title('Scatter-plot-btw-Price & weight of the diamond')

plt.xlabel('weight of the diamond')
plt.ylabel('price')

plt.grid()

plt.show()

# %%
plt.scatter(df['x'], df['price'])

plt.title('Scatter-plot-btw-Price & lentgh of the diamond')

plt.xlabel('lentgh of the diamond')
plt.ylabel('price')

plt.grid()

plt.show()

# %%
plt.scatter(df['y'], df['price'])

plt.title('Scatter-plot-btw-Price & width of the diamond')

plt.xlabel('width of the diamond')
plt.ylabel('price')

plt.grid()

plt.show()

# %%
plt.scatter(df['z'], df['price'])

plt.title('Scatter-plot-btw-Price & depth of the diamond')

plt.xlabel('depth of the diamond')
plt.ylabel('price')

plt.grid()

plt.show()

# %% [markdown]
# ### Diamond Cut vs Price

# %%
fig = plt.figure(figsize = (8,8))
sns.boxplot(y = df.price, x = df.cut)
plt.title("Diamond cut vs Price")
plt.show()

# %% [markdown]
# ### Diamond color vs Price

# %%
fig = plt.figure(figsize = (8,8))
sns.boxplot(y = df.price, x = df.color)
plt.title("Diamond color vs Price")
plt.show()

# %% [markdown]
# ### Diamond clarity vs Price

# %%
fig = plt.figure(figsize = (8,8))
sns.boxplot(y = df.price, x = df.color)
plt.title("Diamond clarity vs Price")
plt.show()

# %% [markdown]
# ### Correlation Plot

# %%
plt.figure(figsize=(15,8))

sns.heatmap(df.corr(), data = df, annot = True, cmap = 'RdBu_r')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %% [markdown]
# ### Data Preparation
# - Train Test Split
# - Encoding for Categorical Columns
#   - Ordinal : LabelEncoding or OrdinalEncoding
#   - Nominal : OneHotEncoding or get_dummies
# - Encoding for Numerical Columns
#   - Standardization (z-transformation)
#
# ### We will be following below mentioned steps:
# 1. Identify the Target Variable and Splitting the Data into train and test
# 2. Separating Categorical and Numerical Columns
# 3. Rescaling Numerical Columns (Standardization or z-transformation)
# 4. Applying OneHotEncoding on Categorical Columns
# 5. Applying Label Encoding on Categorical Columns
# 6. Concatinating the Encoded Categorical Features and Scaled Numerical Features

# %% [markdown]
# ### 1. Identify the Target Variable and Splitting the Data into train and test

# %%
y = df['price']

X = df.drop('price', axis = 'columns')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 10)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (37758, 9) (37758,)
# (16182, 9) (16182,)

# %% [markdown]
# ### 2. Separating Categorical and Numerical Columns

# %%
X_train.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include = ['object'])

X_train_cat.head()
# Out:
#              cut color clarity
# 23590      Ideal     E      IF
# 20122      Ideal     H      IF
# 41416      Ideal     H     SI1
# 19392  Very Good     H     SI1
# 48949      Ideal     J     SI2

# %%
X_train_num = X_train.select_dtypes(include = ['int64', 'float64'])

X_train_num.head()
# Out:
#        carat  depth  table     x     y     z
# 23590   1.02   62.6   57.0  6.47  6.41  4.03
# 20122   1.23   61.3   57.0  6.92  6.87  4.23
# 41416   0.53   62.4   59.0  5.18  5.21  3.24
# 19392   1.50   62.9   56.0  7.24  7.33  4.58
# 48949   0.70   61.6   57.0  5.73  5.69  3.52

# %% [markdown]
# ### 3. Ordinal Encoderfor categorical features

# %%
from sklearn.preprocessing import OrdinalEncoder


le = OrdinalEncoder()

X_train_cat_le = pd.DataFrame(le.fit_transform(X_train_cat), 
                                    columns = X_train_cat.columns, 
                                    index = X_train_cat.index)

X_train_cat_le.head()
# Out:
#        cut  color  clarity
# 23590  2.0    1.0      1.0
# 20122  2.0    4.0      1.0
# 41416  2.0    4.0      2.0
# 19392  4.0    4.0      2.0
# 48949  2.0    6.0      3.0

# %% [markdown]
# ### 4. Rescaling on Numerical features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#           carat     depth     table         x         y         z
# 23590  0.476637  0.593828 -0.201072  0.665760  0.609753  0.714144
# 20122  0.922237 -0.319016 -0.201072  1.068266  1.021402  1.002914
# 41416 -0.563099  0.453390  0.699227 -0.488091 -0.464115 -0.426497
# 19392  1.495153  0.804484 -0.651222  1.354492  1.433051  1.508261
# 48949 -0.202374 -0.108359 -0.201072  0.003861 -0.034568 -0.022219

# %% [markdown]
# ### 5. Concatinating the Encoded Categorical Features and Scaled Numerical Features:

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_cat_le], axis = 'columns')

X_train_transformed.head()
# Out:
#           carat     depth     table         x         y         z  cut  color  \
# 23590  0.476637  0.593828 -0.201072  0.665760  0.609753  0.714144  2.0    1.0
# 20122  0.922237 -0.319016 -0.201072  1.068266  1.021402  1.002914  2.0    4.0
# 41416 -0.563099  0.453390  0.699227 -0.488091 -0.464115 -0.426497  2.0    4.0
# 19392  1.495153  0.804484 -0.651222  1.354492  1.433051  1.508261  4.0    4.0
# 48949 -0.202374 -0.108359 -0.201072  0.003861 -0.034568 -0.022219  2.0    6.0
#
#        clarity
# 23590      1.0
# 20122      1.0
# 41416      2.0
# 19392      2.0
# 48949      3.0

# %% [markdown]
# ## Same steps of data preprocessing for Test Data

# %%
X_test_cat = X_test.select_dtypes(include = ['object'])

X_test_cat.head()
# Out:
#              cut color clarity
# 8018     Premium     E     SI1
# 1583   Very Good     D     VS1
# 9138   Very Good     H     SI2
# 2787       Ideal     F     VS2
# 52429    Premium     I    VVS1

# %%
X_test_num = X_test.select_dtypes(include = ['int64', 'float64'])

X_test_num.head()
# Out:
#        carat  depth  table     x     y     z
# 8018    1.01   61.7   56.0  6.44  6.39  3.96
# 1583    0.70   60.4   58.0  5.71  5.78  3.47
# 9138    1.13   59.8   59.0  6.75  6.82  4.06
# 2787    0.76   61.0   55.0  5.89  5.92  3.60
# 52429   0.70   61.2   59.0  5.65  5.69  3.47

# %%
X_test_cat_le = pd.DataFrame(le.transform(X_test_cat), 
                                    columns = X_test_cat.columns, 
                                    index = X_test_cat.index)

X_test_cat_le.head()
# Out:
#        cut  color  clarity
# 8018   3.0    1.0      2.0
# 1583   4.0    0.0      4.0
# 9138   4.0    4.0      3.0
# 2787   2.0    2.0      5.0
# 52429  3.0    5.0      6.0

# %%
X_test_num_rescaled = pd.DataFrame(scaler.fit_transform(X_test_num), 
                                    columns = X_test_num.columns, 
                                    index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#           carat     depth     table         x         y         z
# 8018   0.429077 -0.026129 -0.654376  0.615796  0.535834  0.562310
# 1583  -0.216393 -0.921352  0.228904 -0.030016  0.026480 -0.104092
# 9138   0.678936 -1.334532  0.670543  0.890045  0.894887  0.698311
# 2787  -0.091464 -0.508172 -1.096015  0.129225  0.143381  0.072708
# 52429 -0.216393 -0.370446  0.670543 -0.083097 -0.048671 -0.104092

# %%
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_cat_le], axis = 'columns')

X_test_transformed.head()
# Out:
#           carat     depth     table         x         y         z  cut  color  \
# 8018   0.429077 -0.026129 -0.654376  0.615796  0.535834  0.562310  3.0    1.0
# 1583  -0.216393 -0.921352  0.228904 -0.030016  0.026480 -0.104092  4.0    0.0
# 9138   0.678936 -1.334532  0.670543  0.890045  0.894887  0.698311  4.0    4.0
# 2787  -0.091464 -0.508172 -1.096015  0.129225  0.143381  0.072708  2.0    2.0
# 52429 -0.216393 -0.370446  0.670543 -0.083097 -0.048671 -0.104092  3.0    5.0
#
#        clarity
# 8018       2.0
# 1583       4.0
# 9138       3.0
# 2787       5.0
# 52429      6.0

# %% [markdown]
# ### 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression

LinearRegression = LinearRegression()

LinearRegression.fit(X_train_transformed, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = LinearRegression.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual    Predicted
# 8018     4330  5411.019804
# 1583     3008  3836.788484
# 9138     4537  5961.716423
# 2787     3257  4083.747480
# 52429    2513  2874.157604

# %%
from sklearn import metrics
from sklearn.metrics import  r2_score

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))

print('R2_score: ', r2_score(y_test, y_test_pred))
# Out:
# Mean Absolute Error:  861.4199135130789
# Mean Squared Error:  1885607.4003466119
# Root Mean Squared Error:  1373.1742061175676
# R2_score:  0.8849221759157911

# %% [markdown]
# ### 2. KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

KNeighborsRegressor = KNeighborsRegressor()

KNeighborsRegressor.fit(X_train_transformed, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_test_pred = KNeighborsRegressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 8018     4330     4363.0
# 1583     3008     3234.6
# 9138     4537     4600.0
# 2787     3257     3348.8
# 52429    2513     2192.4

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))

print('R2_score: ', r2_score(y_test, y_test_pred))
# Out:
# Mean Absolute Error:  418.5526263749846
# Mean Squared Error:  654508.6087628229
# Root Mean Squared Error:  809.0170633323027
# R2_score:  0.9600556157517396

# %% [markdown]
# ### 3. Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

DecisionTreeRegressor = DecisionTreeRegressor()

DecisionTreeRegressor.fit(X_train_transformed, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_test_pred = DecisionTreeRegressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 8018     4330     4884.0
# 1583     3008     2956.0
# 9138     4537     4561.0
# 2787     3257     2939.0
# 52429    2513     1832.0

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))

print('R2_score: ', r2_score(y_test, y_test_pred))
# Out:
# Mean Absolute Error:  466.59152144357927
# Mean Squared Error:  849576.6010690891
# Root Mean Squared Error:  921.7247968179489
# R2_score:  0.9481506984826655

# %% [markdown]
# ### 4. Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
 
RandomForestRegressor = RandomForestRegressor()

RandomForestRegressor.fit(X_train_transformed, y_train)
# Out:
# RandomForestRegressor()

# %%
y_test_pred = RandomForestRegressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 8018     4330    5258.28
# 1583     3008    3094.19
# 9138     4537    4455.61
# 2787     3257    3072.47
# 52429    2513    2213.24

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))

print('R2_score: ', r2_score(y_test, y_test_pred))
# Out:
# Mean Absolute Error:  359.54078394056296
# Mean Squared Error:  488310.3146512795
# Root Mean Squared Error:  698.7920396307327
# R2_score:  0.9701986275204397

# %%
from pickle import dump

dump(scaler, open('models/standard_scaler.pkl', 'wb'))
dump(le, open('models/lebel_encoder.pkl', 'wb'))
dump(LinearRegression, open('models/lr_model.pkl', 'wb'))
dump(KNeighborsRegressor, open('models/knn_model.pkl', 'wb'))
dump(DecisionTreeRegressor, open('models/dt_model.pkl', 'wb'))
dump(RandomForestRegressor, open('models/rf_model.pkl', 'wb'))

# %% [markdown]
# ## Introduction to Experiment Tracking
# ### Terminologies:
# 1.Experiment
# 2.Run
# 3.Metadata (i.e. Tags, Parameters, Metrics)
# 3.Artifacts (i.e. Output files associated with experiment runs)
#
# ### What do you want to track for each Experiment Run?
# 1.Training and Validation Data Used
# 2.Hyperparameters
# 3.Metrics
# 4.Models
#
# ### Why Track?
# Organization Optimization Reproducibility
#
# ### Tool - MLFlow
# MLFlow helps you to organize your experiments into runs.
#
# ### MLFlow keeps track of:
#
# Tags
#
# Parameters
#
# Metrics
#
# Models
#
# Artifact
#
# Source code, Start and End Time, Authors etc..
#
# ### Run below mentioned commands to install mlflow on your system:
# pip install mlflow
#
# mlflow ui --backend-store-uri sqlite:///mlflow.db

# %% [markdown]
# ## Introduction to MLFlow
#
# ### Step 1 - Import MLFlow
# import mlflow
#
# ### Step 2 - Set the tracker and experiment
# mlflow.set_tracking_uri(DATABASE_URI)
#
# mlflow.set_experiment("EXPERIMENT_NAME")
#
# ### Step 3 - Start a experiment run
# with mlflow.start_run():
#
# ### Step 4 - Logging the metadata
# mlflow.set_tag(KEY, VALUE)
#
# mlflow.log_param(KEY, VALUE)
#
# mlflow.log_metric(KEY, VALUE)
#
# ### Step 5 - Logging the model and other files (2 ways)
# Way 1 - mlflow.<FRAMEWORK>.log_model(MODEL_OBJECT, artifact_path="PATH")
#
# Way 2 - mlflow.log_artifact(LOCAL_PATH, artifact_path="PATH")

# %% [markdown]
# ## Running the Experiment

# %%
import mlflow

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")

mlflow.set_experiment("Diamond Price Prediction")
# Out:
# <Experiment: artifact_location='./mlruns/1', creation_time=1664852380642, experiment_id='1', last_update_time=1664852380642, lifecycle_stage='active', name='Diamond Price Prediction', tags={}>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn import metrics
from sklearn.metrics import  r2_score

# %%
import pickle
from pickle import dump

dump(scaler, open('models/standard_scaler.pkl', 'wb'))
dump(le, open('models/ordinal_encoder.pkl', 'wb'))

# %% [markdown]
# ## Experiment 1 - Training Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
with mlflow.start_run():
    mlflow.set_tag("dev", "Aagvan")
    mlflow.set_tag("algo", "Linear Regression")
    # log the data for each run using log_param, log_metric
    mlflow.log_param("data-path", "data/diamonds.csv")
    linear_regressor = LinearRegression()
    linear_regressor.fit(X_train_transformed, y_train)
    y_test_pred = linear_regressor.predict(X_test_transformed)
    acc = metrics.r2_score(y_test, y_test_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    mlflow.log_metric("R2 Score", acc)
    mlflow.log_metric("RMSE", rmse)
    mlflow.sklearn.log_model(linear_regressor, artifact_path = "models")
    mlflow.log_artifact("models/standard_scaler.pkl")
    mlflow.log_artifact("models/ordinal_encoder.pkl")

# %% [markdown]
# ## Experiment 2 - KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
with mlflow.start_run():
    mlflow.set_tag("dev", "Aagvan")
    mlflow.set_tag("algo", "KNN")
    # log the data for each run using log_param, log_metric
    mlflow.log_param("data-path", "data/diamonds.csv")
    k = 6
    knn_regressor = KNeighborsRegressor(n_neighbors = k)
    knn_regressor.fit(X_train_transformed, y_train)
    y_test_pred = knn_regressor.predict(X_test_transformed)
    acc = metrics.r2_score(y_test, y_test_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    mlflow.log_param("n_neighbors", k)
    mlflow.log_metric("R2 Score", acc)
    mlflow.log_metric("RMSE", rmse)
    mlflow.sklearn.log_model(knn_regressor, artifact_path = "models")
    mlflow.log_artifact("models/standard_scaler.pkl")
    mlflow.log_artifact("models/ordinal_encoder.pkl")

# %% [markdown]
# ## Experiment 3 - Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
with mlflow.start_run():
    mlflow.set_tag("dev", "Aagvan")
    mlflow.set_tag("algo", "Decision Tree Regression")
    # log the data for each run using log_param, log_metric
    mlflow.log_param("data-path", "data/diamonds.csv")
    d = None
    dt_regressor = DecisionTreeRegressor(max_depth = d)
    dt_regressor.fit(X_train_transformed, y_train)
    y_test_pred = dt_regressor.predict(X_test_transformed)
    acc = metrics.r2_score(y_test, y_test_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    mlflow.log_param("max_depth", d)
    mlflow.log_metric("R2 Score", acc)
    mlflow.log_metric("RMSE", rmse)
    mlflow.sklearn.log_model(dt_regressor, artifact_path = "models")
    mlflow.log_artifact("models/standard_scaler.pkl")
    mlflow.log_artifact("models/ordinal_encoder.pkl")

# %% [markdown]
# ## Experiment 4 - Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
with mlflow.start_run():
    mlflow.set_tag("dev", "Aagvan")
    mlflow.set_tag("algo", "Random Forest")
    # log the data for each run using log_param, log_metric
    mlflow.log_param("data-path", "data/diamonds.csv")
    e = 101
    rf_regressor = RandomForestRegressor(n_estimators = e)
    rf_regressor.fit(X_train_transformed, y_train)
    y_test_pred = rf_regressor.predict(X_test_transformed)
    acc = metrics.r2_score(y_test, y_test_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    mlflow.log_param("n_estimators", e)
    mlflow.log_metric("R2 Score", acc)
    mlflow.log_metric("RMSE", rmse)
    mlflow.sklearn.log_model(rf_regressor, artifact_path = "models")
    mlflow.log_artifact("models/standard_scaler.pkl")
    mlflow.log_artifact("models/ordinal_encoder.pkl")
